# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
from mpl_toolkits.mplot3d import Axes3D
import plotly.graph_objs as go

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import warnings
import os
from pathlib import Path
warnings.filterwarnings("ignore")

# %%
data = pd.read_excel('data_SK.xlsx', sheet_name='ผลตอบแทน (6263-6566) ภาษาอังกฤษ')
data
# Out:
#      factory  year unit_zone  zone      director_zone          explorer  \
# 0         SK  6162        บน     1  อนิรุตต์ ศรีสุนทร  ไม่มีนักส่งเสริม
# 1         SK  6162        บน     1  อนิรุตต์ ศรีสุนทร  ไม่มีนักส่งเสริม
# 2         SK  6162        บน     1  อนิรุตต์ ศรีสุนทร  ไม่มีนักส่งเสริม
# 3         SK  6162        บน     1  อนิรุตต์ ศรีสุนทร  ไม่มีนักส่งเสริม
# 4         SK  6162        บน     1  อนิรุตต์ ศรีสุนทร  ไม่มีนักส่งเสริม
# ...      ...   ...       ...   ...                ...               ...
# 4092      SK  6566      ล่าง    17   กมลชาติ ชัยพุทธา       ภูเบศ ขันคำ
# 4093      SK  6566      ล่าง    17   กมลชาติ ชัยพุทธา       ภูเบศ ขันคำ
# 4094      SK  6566      ล่าง    17   กมลชาติ ชัยพุทธา       ภูเบศ ขันคำ
# 4095      SK  6566      ล่าง    17   กมลชาติ ชัยพุทธา       ภูเบศ ขันคำ
# 4096      SK  6566      ล่าง    17   กมลชาติ ชัยพุทธา       ภูเบศ ขันคำ
#
#                             type  quota                quota : name  \
# 0                       ปลอดภาระ  10486       10486 : สลิน เปียมั่น
# 1                       ปลอดภาระ  10487     10487 : เอมอร ภาวะโพธิ์
# 2                       ปลอดภาระ  10492       10492 : สมเพชร พรสงวน
# 3                       ปลอดภาระ  10896        10896 : เรือง ผาสีดา
# 4                       ปลอดภาระ  11203       11203 : กฤต กรเดชากุล
# ...                          ...    ...                         ...
# 4092  หนี้มีปัญหา ไม่ส่งเสริมต่อ  10310   10310 : วีระพงษ์ นามขันธ์
# 4093  หนี้มีปัญหา ไม่ส่งเสริมต่อ  10323      10323 : แดง ไชยพิทักษ์
# 4094  หนี้มีปัญหา ยังส่งเสริมต่อ  10243     10243 : นำสมัย ฐานทองดี
# 4095  หนี้มีปัญหา ยังส่งเสริมต่อ  10324     10324 : ชัยรัตน์ โสมชัย
# 4096  หนี้มีปัญหา ยังส่งเสริมต่อ  10426  10426 : เลืองเดช แสงสิทธิ์
#
#       weight (tons)    net return        debt  sugar cane procurement  \
# 0              0.00  3.142144e+04   -31421.44                     0.0
# 1              0.00  3.208680e+04   -32086.80                     0.0
# 2              0.00  2.898131e+04   -28981.31                     0.0
# 3              0.00  0.000000e+00        0.00                     0.0
# 4              0.00 -2.369373e+06  2369372.62                     0.0
# ...             ...           ...         ...                     ...
# 4092          91.19  1.439358e+05   -93127.79                     0.0
# 4093          13.09  1.687858e+04    -9585.27                     0.0
# 4094          53.45  2.487143e+04     4909.13                     0.0
# 4095          19.91 -2.167469e+04    32767.88                     0.0
# 4096         212.23  8.524561e+04    33001.89                     0.0
#
#            spend
# 0      -31421.44
# 1      -32086.80
# 2      -28981.31
# 3           0.00
# 4     2369372.62
# ...          ...
# 4092   -93127.79
# 4093    -9585.27
# 4094     4909.13
# 4095    32767.88
# 4096    33001.89
#
# [4097 rows x 14 columns]

# %%
data.hist(figsize = (15,10))
# Out:
# array([[<AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'zone'}>,
#         <AxesSubplot:title={'center':'quota'}>],
#        [<AxesSubplot:title={'center':'weight (tons)'}>,
#         <AxesSubplot:title={'center':'net return'}>,
#         <AxesSubplot:title={'center':'debt'}>],
#        [<AxesSubplot:title={'center':'sugar cane procurement'}>,
#         <AxesSubplot:title={'center':'spend'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
#รายละเอียดข้อมูล

data.describe()
# Out:
#               year         zone         quota  weight (tons)    net return  \
# count  4097.000000  4097.000000   4097.000000    4097.000000  4.097000e+03
# mean   6410.765194     7.606053  11426.660483     318.157937  3.355711e+04
# std     141.984317     5.339320    943.403432     768.723104  4.085139e+05
# min    6162.000000     1.000000  10001.000000       0.000000 -7.342775e+06
# 25%    6263.000000     3.000000  10610.000000       9.040000  3.519225e+02
# 50%    6465.000000     6.000000  11314.000000      74.060000  2.738092e+04
# 75%    6566.000000    14.000000  12204.000000     236.670000  8.226807e+04
# max    6566.000000    17.000000  13779.000000    9193.250000  2.834873e+06
#
#                debt  sugar cane procurement         spend
# count  4.097000e+03            4.097000e+03  4.097000e+03
# mean   5.733370e+04           -5.102699e+04  6.306702e+03
# std    3.835411e+05            3.004250e+05  4.859832e+05
# min   -1.143915e+06           -3.334832e+06 -3.334832e+06
# 25%    0.000000e+00            0.000000e+00 -9.000000e+03
# 50%    0.000000e+00            0.000000e+00  0.000000e+00
# 75%    6.516000e+03            0.000000e+00  0.000000e+00
# max    8.610000e+06            0.000000e+00  8.548544e+06

# %% [markdown]
# ## แปลงข้อมูลให้อยู่ในมาตรฐานเดียวกันด้วยวิธีของ yeo-johnson

# %%
from sklearn import preprocessing

# %%
data.columns
# Out:
# Index(['factory', 'year', 'unit_zone', 'zone', 'director_zone', 'explorer',
#        'type', 'quota', 'quota : name', 'weight (tons)', 'net return', 'debt',
#        'sugar cane procurement', 'spend'],
#       dtype='object')

# %%
#แปลงข้อมูลด้วย yeo-johnson (แปลงให้ข้อมูลอยู่ในมาตรฐานเดียวกัน)

cols = ['weight (tons)', 'net return', 'spend']
pt = preprocessing.PowerTransformer(method = 'yeo-johnson', standardize = True)
mat = pt.fit_transform(data[cols])
mat[:5].round(4)
# Out:
# array([[-1.4667, -0.1444, -0.0515],
#        [-1.4667, -0.1421, -0.053 ],
#        [-1.4667, -0.1529, -0.0459],
#        [-1.4667, -0.2495,  0.0202],
#        [-1.4667, -3.8011,  4.3176]])

# %%
yj_cols = [f'yj_{c}' for c in cols]
yj_cols
# Out:
# ['yj_weight (tons)', 'yj_net return', 'yj_spend']

# %%
#แสดงในรูปแบบตาราง

trans_data = pd.concat([data, pd.DataFrame(mat, columns = yj_cols)], axis = 'columns')  #, pd.DataFrame(z, columns = z_cols)], axis = 'columns')
trans_data
# Out:
#      factory  year unit_zone  zone      director_zone          explorer  \
# 0         SK  6162        บน     1  อนิรุตต์ ศรีสุนทร  ไม่มีนักส่งเสริม
# 1         SK  6162        บน     1  อนิรุตต์ ศรีสุนทร  ไม่มีนักส่งเสริม
# 2         SK  6162        บน     1  อนิรุตต์ ศรีสุนทร  ไม่มีนักส่งเสริม
# 3         SK  6162        บน     1  อนิรุตต์ ศรีสุนทร  ไม่มีนักส่งเสริม
# 4         SK  6162        บน     1  อนิรุตต์ ศรีสุนทร  ไม่มีนักส่งเสริม
# ...      ...   ...       ...   ...                ...               ...
# 4092      SK  6566      ล่าง    17   กมลชาติ ชัยพุทธา       ภูเบศ ขันคำ
# 4093      SK  6566      ล่าง    17   กมลชาติ ชัยพุทธา       ภูเบศ ขันคำ
# 4094      SK  6566      ล่าง    17   กมลชาติ ชัยพุทธา       ภูเบศ ขันคำ
# 4095      SK  6566      ล่าง    17   กมลชาติ ชัยพุทธา       ภูเบศ ขันคำ
# 4096      SK  6566      ล่าง    17   กมลชาติ ชัยพุทธา       ภูเบศ ขันคำ
#
#                             type  quota                quota : name  \
# 0                       ปลอดภาระ  10486       10486 : สลิน เปียมั่น
# 1                       ปลอดภาระ  10487     10487 : เอมอร ภาวะโพธิ์
# 2                       ปลอดภาระ  10492       10492 : สมเพชร พรสงวน
# 3                       ปลอดภาระ  10896        10896 : เรือง ผาสีดา
# 4                       ปลอดภาระ  11203       11203 : กฤต กรเดชากุล
# ...                          ...    ...                         ...
# 4092  หนี้มีปัญหา ไม่ส่งเสริมต่อ  10310   10310 : วีระพงษ์ นามขันธ์
# 4093  หนี้มีปัญหา ไม่ส่งเสริมต่อ  10323      10323 : แดง ไชยพิทักษ์
# 4094  หนี้มีปัญหา ยังส่งเสริมต่อ  10243     10243 : นำสมัย ฐานทองดี
# 4095  หนี้มีปัญหา ยังส่งเสริมต่อ  10324     10324 : ชัยรัตน์ โสมชัย
# 4096  หนี้มีปัญหา ยังส่งเสริมต่อ  10426  10426 : เลืองเดช แสงสิทธิ์
#
#       weight (tons)    net return        debt  sugar cane procurement  \
# 0              0.00  3.142144e+04   -31421.44                     0.0
# 1              0.00  3.208680e+04   -32086.80                     0.0
# 2              0.00  2.898131e+04   -28981.31                     0.0
# 3              0.00  0.000000e+00        0.00                     0.0
# 4              0.00 -2.369373e+06  2369372.62                     0.0
# ...             ...           ...         ...                     ...
# 4092          91.19  1.439358e+05   -93127.79                     0.0
# 4093          13.09  1.687858e+04    -9585.27                     0.0
# 4094          53.45  2.487143e+04     4909.13                     0.0
# 4095          19.91 -2.167469e+04    32767.88                     0.0
# 4096         212.23  8.524561e+04    33001.89                     0.0
#
#            spend  yj_weight (tons)  yj_net return  yj_spend
# 0      -31421.44         -1.466658      -0.144418 -0.051505
# 1      -32086.80         -1.466658      -0.142114 -0.053040
# 2      -28981.31         -1.466658      -0.152853 -0.045880
# 3           0.00         -1.466658      -0.249524  0.020245
# 4     2369372.62         -1.466658      -3.801051  4.317562
# ...          ...               ...            ...       ...
# 4092   -93127.79          0.215838       0.258168 -0.194732
# 4093    -9585.27         -0.558862      -0.194274 -0.001385
# 4094     4909.13         -0.013460      -0.167003  0.029716
# 4095    32767.88         -0.405772      -0.287787  0.082275
# 4096    33001.89          0.601970       0.045716  0.082713
#
# [4097 rows x 17 columns]

# %%
#plot กราฟดูข้อมูล (ยังไม่แปลงข้อมูล)

trans_data[cols].hist(layout = (1, len(cols)), figsize = (3*len(cols), 2));

# %%
#plot กราฟดูข้อมูล (แปลงข้อมูลแล้ว)

trans_data[yj_cols].hist(layout = (1, len(cols)), figsize = (3*len(cols), 2));

# %%
#แสดงตัวอย่างนิดหน่อยของข้อมูลที่ถูกแปลงให้อยู่ในมาตรฐานเดียวกันแล้ว

X = pd.DataFrame(mat, columns = cols)
X.head()
# Out:
#    weight (tons)  net return     spend
# 0      -1.466658   -0.144418 -0.051505
# 1      -1.466658   -0.142114 -0.053040
# 2      -1.466658   -0.152853 -0.045880
# 3      -1.466658   -0.249524  0.020245
# 4      -1.466658   -3.801051  4.317562

# %%
#มีข้อมูลที่เป็น null มั้ย

trans_data[yj_cols].isnull().sum()
# Out:
# yj_weight (tons)    0
# yj_net return       0
# yj_spend            0
# dtype: int64

# %% [markdown]
# ## หาจำนวนกลุ่มที่เหมาะสมด้วยวิธี Elbow

# %%
ssd = []
for k in range(1, 10):
    m = KMeans(n_clusters = k)
    m.fit(X)
    ssd.append([k, m.inertia_])
ssd
# Out:
# [[1, 12290.99999999999],
#  [2, 9269.691713008631],
#  [3, 7126.755476408649],
#  [4, 5191.060486291337],
#  [5, 3252.421048877629],
#  [6, 2495.7593518498134],
#  [7, 1956.750220928201],
#  [8, 1612.9699197502791],
#  [9, 1394.57948216552]]

# %%
xy = np.array(ssd)
print(xy)
# Out:
# [[1.00000000e+00 1.22910000e+04]
#  [2.00000000e+00 9.26969171e+03]
#  [3.00000000e+00 7.12675548e+03]
#  [4.00000000e+00 5.19106049e+03]
#  [5.00000000e+00 3.25242105e+03]
#  [6.00000000e+00 2.49575935e+03]
#  [7.00000000e+00 1.95675022e+03]
#  [8.00000000e+00 1.61296992e+03]
#  [9.00000000e+00 1.39457948e+03]]

# %%
trans_data.columns
# Out:
# Index(['factory', 'year', 'unit_zone', 'zone', 'director_zone', 'explorer',
#        'type', 'quota', 'quota : name', 'weight (tons)', 'net return', 'debt',
#        'sugar cane procurement', 'spend', 'yj_weight (tons)', 'yj_net return',
#        'yj_spend'],
#       dtype='object')

# %%
#ใช้ข้อมูลที่แปลงแล้วมาหา cluster ที่เหมาะสม

new_data = trans_data[['yj_weight (tons)', 'yj_net return', 'yj_spend']]

# %%
visualizer = KElbowVisualizer(KMeans(init = 'k-means++', random_state = 100), k = (1,12), timings = False)
visualizer.fit(new_data)
visualizer.show()
n_clusters = visualizer.elbow_value_
print("Optimal number of clusters :", n_clusters)
# Out:
# Optimal number of clusters : 5

# %% [markdown]
# ## Plot กราฟ 3 มิติ ที่จัดกลุ่มแล้ว

# %%
use_data = trans_data[['weight (tons)', 'net return', 'spend']]

# %%
km = KMeans(5)
clusts = km.fit_predict(use_data)

# %%
#คำสั่งนี้สามารถหมุนกราฟได้ 360 องศา

#%matplotlib qt
#%pylab qt

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
scatter = ax.scatter(km.cluster_centers_[:, 0],
            km.cluster_centers_[:, 1],
            km.cluster_centers_[:, 2],
            s = 50,
            marker = 'o',
            c = 'red',
            label = 'centroids')
scatter = ax.scatter(use_data['weight (tons)'], use_data['net return'], use_data['spend'], c = clusts, s = 10)


ax.set_title('K-Means Clustering')
ax.set_xlabel('weight (tons)')
ax.set_ylabel('net return')
ax.set_zlabel('spend')
ax.legend()
plt.show()

# %% [markdown]
# ## save ข้อมูลเป็นไฟล์ xlsx โดย K = 5

# %%
model = KMeans(n_clusters = 5)
model
# Out:
# KMeans(n_clusters=5)

# %%
model.fit(use_data)
# Out:
# KMeans(n_clusters=5)

# %%
trans_data['cluster'] = model.labels_
trans_data.head()
# Out:
#   factory  year unit_zone  zone      director_zone          explorer  \
# 0      SK  6162        บน     1  อนิรุตต์ ศรีสุนทร  ไม่มีนักส่งเสริม
# 1      SK  6162        บน     1  อนิรุตต์ ศรีสุนทร  ไม่มีนักส่งเสริม
# 2      SK  6162        บน     1  อนิรุตต์ ศรีสุนทร  ไม่มีนักส่งเสริม
# 3      SK  6162        บน     1  อนิรุตต์ ศรีสุนทร  ไม่มีนักส่งเสริม
# 4      SK  6162        บน     1  อนิรุตต์ ศรีสุนทร  ไม่มีนักส่งเสริม
#
#        type  quota             quota : name  weight (tons)  net return  \
# 0  ปลอดภาระ  10486    10486 : สลิน เปียมั่น            0.0    31421.44
# 1  ปลอดภาระ  10487  10487 : เอมอร ภาวะโพธิ์            0.0    32086.80
# 2  ปลอดภาระ  10492    10492 : สมเพชร พรสงวน            0.0    28981.31
# 3  ปลอดภาระ  10896     10896 : เรือง ผาสีดา            0.0        0.00
# 4  ปลอดภาระ  11203    11203 : กฤต กรเดชากุล            0.0 -2369372.62
#
#          debt  sugar cane procurement       spend  yj_weight (tons)  \
# 0   -31421.44                     0.0   -31421.44         -1.466658
# 1   -32086.80                     0.0   -32086.80         -1.466658
# 2   -28981.31                     0.0   -28981.31         -1.466658
# 3        0.00                     0.0        0.00         -1.466658
# 4  2369372.62                     0.0  2369372.62         -1.466658
#
#    yj_net return  yj_spend  cluster
# 0      -0.144418 -0.051505        1
# 1      -0.142114 -0.053040        1
# 2      -0.152853 -0.045880        1
# 3      -0.249524  0.020245        1
# 4      -3.801051  4.317562        3

# %%
trans_data.to_excel("cluster รวม 2 เขต = 5.xlsx")
